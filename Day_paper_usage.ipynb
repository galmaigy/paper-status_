# %%
import folium
from IPython.display import display
import pandas as pd
import numpy as np

# %%
df_day = pd.read_excel('data/day.xlsx', index_col = 'name', dtype={'estimated': int})
display(df_day)
# Out:
#                                   PharmacyID fac_id  pack  estimated  \
# name
# PR - AMHERST MEADOWS                   1PITT     15   561        785
# PR - THE AVENUE AT AURORA              1PITT     16   699        979
# PR - THE AVE AT BROADVIEW HEIGHTS      1PITT     17   136        191
# PR - THE AVENUE AT MACEDONIA           1PITT     19   530        743
# PR - THE AVENUE AT MEDINA              1PITT     20   606        848
# ...                                      ...    ...   ...        ...
# PL - VASONA CREEK                      6FRES  P6002  1152       1613
# PL - CYPRESS RIDGE                     6FRES  P6003   702        983
# TH - BOONVILLE NORTH                   3INDI  T1401   502        702
# TH - BOONVILLE                         3INDI  T1402   897       1256
# TH - OWENSVILLE                        3INDI  T1403   711        996
#
#                                     latitude   longitude
# name
# PR - AMHERST MEADOWS               40.816110  -81.524592
# PR - THE AVENUE AT AURORA          41.305311  -81.344200
# PR - THE AVE AT BROADVIEW HEIGHTS  41.306386  -81.684873
# PR - THE AVENUE AT MACEDONIA       41.311080  -81.506960
# PR - THE AVENUE AT MEDINA          41.136040  -81.850660
# ...                                      ...         ...
# PL - VASONA CREEK                  37.230190 -121.964580
# PL - CYPRESS RIDGE                 36.592915 -121.916455
# TH - BOONVILLE NORTH               38.058390  -87.270389
# TH - BOONVILLE                     38.043290  -87.278657
# TH - OWENSVILLE                    38.269941  -87.702726
#
# [183 rows x 6 columns]

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, PR - AMHERST MEADOWS to TH - OWENSVILLE
# Data columns (total 6 columns):
# PharmacyID    183 non-null object
# fac_id        183 non-null object
# pack          183 non-null int64
# estimated     183 non-null int32
# latitude      183 non-null float64
# longitude     183 non-null float64
# dtypes: float64(2), int32(1), int64(1), object(2)
# memory usage: 9.3+ KB

# %%
df_map = df_day.copy()


base_map = folium.Map(location=[37.0902 , -95.7129],
                        zoom_start=5,
                        tiles='Stamen Toner')

base_map

base_map.save('map/base_map.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-f88d5b1b3f43> in <module>
#       8 base_map
#       9
# ---> 10 base_map.save('map/base_map.html')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\branca\element.py in save(self, outfile, close_file, **kwargs)
#     162         """
#     163         if isinstance(outfile, text_type) or isinstance(outfile, binary_type):
# --> 164             fid = open(outfile, 'wb')
#     165         else:
#     166             fid = outfile
#
# FileNotFoundError: [Errno 2] No such file or directory: 'map/base_map.html'

# %%
def color(est): 
    if est in range(0,400): 
        col = 'green'
    elif est in range(401,800): 
        col = 'yellow'
    elif est in range(801,1200): 
        col = 'orange'
    else: 
        col='red'
    return col 

for name, lat, lng, est in zip(df_map.index, df_map.latitude, df_map.longitude, df_map.estimated):
    folium.CircleMarker(location = [lat,lng],
                        radius = 5, 
                        color = color(est),
                        fill =True, 
#                         fill_color ='coral',
                        fill_opacity =0.7,
                        popup= [name,est] 
                       ).add_to(base_map)

# folium.Marker([40.3675689, -80.1093305], popup='HUB',icon=folium.Icon(color='blue', icon='home')).add_to(pa_map_)

display(base_map)
base_map.save('map/day.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_day.to_excel('day_save.xlsx')
