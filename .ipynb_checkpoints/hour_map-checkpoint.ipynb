# %%
import folium
from IPython.display import display
import pandas as pd
import numpy as np

# %%
df_hour = pd.read_excel('data/hour.xlsx',  dtype={'leftover': int, 'cum':int})
display(df_hour)
# Out:
#      PharmacyID fac_id         id  runthis  hour  pack  estimated   cum  \
# 0         1PITT     15     152600     2600     0    33       46.2    46
# 1         1PITT     15     152601     2601     1     2        2.8    49
# 2         1PITT     15     152603     2603     3     3        4.2    53
# 3         1PITT     15     152605     2605     5     1        1.4    54
# 4         1PITT     15     152607     2607     7     1        1.4    56
# ...         ...    ...        ...      ...   ...   ...        ...   ...
# 5386      6FRES  P6003  P60032813     2813    13     6        8.4  2889
# 5387      6FRES  P6003  P60032816     2816    16     1        1.4  2891
# 5388      6FRES  P6003  P60032820     2820    20    15       21.0  2912
# 5389      6FRES  P6003  P60032822     2822    22     5        7.0  2919
# 5390      6FRES  P6003  P60032823     2823    23    11       15.4  2934
#
#       leftover                  name   latitude   longitude
# ...

# %%
df_copy = df_hour.copy()

mask = df_copy.PharmacyID.isin(['1PITT','3INDI'])
df_map = df_copy.loc[mask,:]
#df_map=df_map[df_map.PharmacyID.isin(['1PITT','3INDI','4KCTY'])]

display(df_map)
# Out:
#      PharmacyID fac_id         id  runthis  hour  pack  estimated   cum  \
# 0         1PITT     15     152600     2600     0    33       46.2    46
# 1         1PITT     15     152601     2601     1     2        2.8    49
# 2         1PITT     15     152603     2603     3     3        4.2    53
# 3         1PITT     15     152605     2605     5     1        1.4    54
# 4         1PITT     15     152607     2607     7     1        1.4    56
# ...         ...    ...        ...      ...   ...   ...        ...   ...
# 3525      3INDI  T1403  T14032817     2817    17     3        4.2  2083
# 3526      3INDI  T1403  T14032818     2818    18   355      497.0  2580
# 3527      3INDI  T1403  T14032819     2819    19   307      429.8  3010
# 3528      3INDI  T1403  T14032820     2820    20     3        4.2  3014
# 3529      3INDI  T1403  T14032821     2821    21     2        2.8  3017
#
#       leftover                  name   latitude  longitude
# ...

# %%
base_map = folium.Map(location=[39.9612 , -82.9988],
                        zoom_start=6,
                        tiles='Stamen Toner')

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cum_list = df_map[['latitude','longitude','cum']].values.tolist()
cum_list
# Out:
# [[40.81611, -81.524592, 46.0],
#  [40.81611, -81.524592, 49.0],
#  [40.81611, -81.524592, 53.0],
#  [40.81611, -81.524592, 54.0],
#  [40.81611, -81.524592, 56.0],
#  [40.81611, -81.524592, 58.0],
#  [40.81611, -81.524592, 60.0],
#  [40.81611, -81.524592, 61.0],
#  [40.81611, -81.524592, 413.0],
#  [40.81611, -81.524592, 743.0],
#  [40.81611, -81.524592, 744.0],
#  [40.81611, -81.524592, 749.0],
#  [40.81611, -81.524592, 765.0],
#  [40.81611, -81.524592, 813.0],
#  [40.81611, -81.524592, 814.0],
#  [40.81611, -81.524592, 817.0],
#  [40.81611, -81.524592, 819.0],
#  [40.81611, -81.524592, 823.0],
#  [40.81611, -81.524592, 834.0],
#  [40.81611, -81.524592, 835.0],
#  [40.81611, -81.524592, 903.0],
#  [40.81611, -81.524592, 1120.0],
#  [40.81611, -81.524592, 1478.0],
#  [40.81611, -81.524592, 1481.0],
#  [40.81611, -81.524592, 1509.0],
#  [40.81611, -81.524592, 1516.0],
#  [40.81611, -81.524592, 1531.0],
#  [40.81611, -81.524592, 1534.0],
#  [40.81611, -81.524592, 1542.0],
# ...

# %%
from folium.plugins import HeatMapWithTime

m=HeatMapWithTime(cum_list, radius=5, gradient={500: 'blue', 1500: 'lime', 2500: 'orange', 3500: 'red'}, min_opacity=0.5, max_opacity=0.8, use_local_extrema=True).add_to(base_map)
m.save('HeatMapWithTime_hour_1.html')
